# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Load data

# %%
df = pd.read_csv('data.csv')

# %%
df.shape
# Out:
# (30697, 25)

# %%
df.dtypes
# Out:
# action_type            object
# combined_shot_type     object
# game_event_id           int64
# game_id                 int64
# lat                   float64
# loc_x                   int64
# loc_y                   int64
# lon                   float64
# minutes_remaining       int64
# period                  int64
# playoffs                int64
# season                 object
# seconds_remaining       int64
# shot_distance           int64
# shot_made_flag        float64
# shot_type              object
# shot_zone_area         object
# shot_zone_basic        object
# shot_zone_range        object
# team_id                 int64
# team_name              object
# game_date              object
# matchup                object
# opponent               object
# shot_id                 int64
# dtype: object

# %%
df.describe().T
# Out:
#                      count          mean           std           min  \
# game_event_id      30697.0  2.491908e+02  1.500037e+02  2.000000e+00
# game_id            30697.0  2.476407e+07  7.755175e+06  2.000001e+07
# lat                30697.0  3.395319e+01  8.779136e-02  3.325330e+01
# loc_x              30697.0  7.110499e+00  1.101246e+02 -2.500000e+02
# loc_y              30697.0  9.110753e+01  8.779136e+01 -4.400000e+01
# lon                30697.0 -1.182627e+02  1.101246e-01 -1.185198e+02
# minutes_remaining  30697.0  4.885624e+00  3.449897e+00  0.000000e+00
# period             30697.0  2.519432e+00  1.153665e+00  1.000000e+00
# playoffs           30697.0  1.465616e-01  3.536741e-01  0.000000e+00
# seconds_remaining  30697.0  2.836508e+01  1.747895e+01  0.000000e+00
# shot_distance      30697.0  1.343744e+01  9.374189e+00  0.000000e+00
# shot_made_flag     25697.0  4.461610e-01  4.971026e-01  0.000000e+00
# team_id            30697.0  1.610613e+09  0.000000e+00  1.610613e+09
# shot_id            30697.0  1.534900e+04  8.861605e+03  1.000000e+00
#
#                             25%           50%           75%           max
# game_event_id      1.100000e+02  2.530000e+02  3.680000e+02  6.590000e+02
# game_id            2.050008e+07  2.090035e+07  2.960047e+07  4.990009e+07
# lat                3.388430e+01  3.397030e+01  3.404030e+01  3.408830e+01
# loc_x             -6.800000e+01  0.000000e+00  9.500000e+01  2.480000e+02
# loc_y              4.000000e+00  7.400000e+01  1.600000e+02  7.910000e+02
# lon               -1.183378e+02 -1.182698e+02 -1.181748e+02 -1.180218e+02
# minutes_remaining  2.000000e+00  5.000000e+00  8.000000e+00  1.100000e+01
# period             1.000000e+00  3.000000e+00  3.000000e+00  7.000000e+00
# playoffs           0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# seconds_remaining  1.300000e+01  2.800000e+01  4.300000e+01  5.900000e+01
# shot_distance      5.000000e+00  1.500000e+01  2.100000e+01  7.900000e+01
# shot_made_flag     0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# team_id            1.610613e+09  1.610613e+09  1.610613e+09  1.610613e+09
# shot_id            7.675000e+03  1.534900e+04  2.302300e+04  3.069700e+04

# %% [markdown]
# # Explore columns

# %%
df.take(np.random.permutation(len(df))[:5]).T
# Out:
#                                     30052               26961  \
# action_type                     Jump Shot           Jump Shot
# combined_shot_type              Jump Shot           Jump Shot
# game_event_id                         435                 326
# game_id                          49600041            40100403
# lat                               33.9043             33.3863
# loc_x                                 107                -132
# loc_y                                 140                 658
# lon                              -118.163            -118.402
# minutes_remaining                       2                   0
# period                                  4                   3
# playoffs                                1                   1
# season                            1996-97             2001-02
# seconds_remaining                       0                   0
# shot_distance                          17                  67
# shot_made_flag                          0                   0
# shot_type                  2PT Field Goal      3PT Field Goal
# shot_zone_area      Right Side Center(RC)      Back Court(BC)
# shot_zone_basic                 Mid-Range           Backcourt
# shot_zone_range                 16-24 ft.     Back Court Shot
# team_id                        1610612747          1610612747
# team_name              Los Angeles Lakers  Los Angeles Lakers
# game_date                      1997-05-04          2002-06-09
# matchup                         LAL @ UTA           LAL @ NJN
# opponent                              UTA                 NJN
# shot_id                             30053               26962
#
#                                  19729                 20563  \
# action_type                  Jump Shot             Jump Shot
# combined_shot_type           Jump Shot             Jump Shot
# game_event_id                       13                   292
# game_id                       21200256              21200830
# lat                            34.0873               33.9153
# loc_x                              -98                  -139
# loc_y                              -43                   129
# lon                           -118.368              -118.409
# minutes_remaining                   10                    10
# period                               1                     3
# playoffs                             0                     0
# season                         2012-13               2012-13
# seconds_remaining                   23                    51
# shot_distance                       10                    18
# shot_made_flag                       0                     1
# shot_type               2PT Field Goal        2PT Field Goal
# shot_zone_area            Left Side(L)  Left Side Center(LC)
# shot_zone_basic              Mid-Range             Mid-Range
# shot_zone_range               8-16 ft.             16-24 ft.
# team_id                     1610612747            1610612747
# team_name           Los Angeles Lakers    Los Angeles Lakers
# game_date                   2012-12-04            2013-02-24
# matchup                      LAL @ HOU             LAL @ DAL
# opponent                           HOU                   DAL
# shot_id                          19730                 20564
#
#                                  18285
# action_type                  Jump Shot
# combined_shot_type           Jump Shot
# game_event_id                       92
# game_id                       21100125
# lat                            33.7903
# loc_x                              -48
# loc_y                              254
# lon                           -118.318
# minutes_remaining                    3
# period                               1
# playoffs                             0
# season                         2011-12
# seconds_remaining                   38
# shot_distance                       25
# shot_made_flag                       1
# shot_type               3PT Field Goal
# shot_zone_area               Center(C)
# shot_zone_basic      Above the Break 3
# shot_zone_range                24+ ft.
# team_id                     1610612747
# team_name           Los Angeles Lakers
# game_date                   2012-01-08
# matchup                    LAL vs. MEM
# opponent                           MEM
# shot_id                          18286

# %%
not_needed = ['game_event_id', 'game_id', 'team_id', 'team_name', 'matchup']

# %%
not_needed
# Out:
# ['game_event_id', 'game_id', 'team_id', 'team_name', 'matchup']

# %%
df.action_type.value_counts()
# Out:
# Jump Shot                             18880
# Layup Shot                             2567
# Driving Layup Shot                     1978
# Turnaround Jump Shot                   1057
# Fadeaway Jump Shot                     1048
# Running Jump Shot                       926
# Pullup Jump shot                        476
# Turnaround Fadeaway shot                439
# Slam Dunk Shot                          411
# Reverse Layup Shot                      395
# Jump Bank Shot                          333
# Driving Dunk Shot                       310
# Dunk Shot                               262
# Tip Shot                                182
# Alley Oop Dunk Shot                     122
# Step Back Jump shot                     118
# Floating Jump shot                      114
# Driving Reverse Layup Shot               97
# Hook Shot                                84
# Driving Finger Roll Shot                 82
# Alley Oop Layup shot                     80
# Reverse Dunk Shot                        75
# Running Layup Shot                       72
# Turnaround Bank shot                     71
# Driving Finger Roll Layup Shot           69
# Driving Slam Dunk Shot                   48
# Running Bank shot                        48
# Running Hook Shot                        41
# Finger Roll Layup Shot                   33
# Fadeaway Bank shot                       31
# Finger Roll Shot                         28
# Driving Jump shot                        28
# Jump Hook Shot                           24
# Running Dunk Shot                        19
# Reverse Slam Dunk Shot                   16
# Follow Up Dunk Shot                      15
# Putback Layup Shot                       15
# Turnaround Hook Shot                     14
# Driving Hook Shot                        14
# Pullup Bank shot                         12
# Running Reverse Layup Shot               11
# Running Finger Roll Layup Shot            6
# Cutting Layup Shot                        6
# Driving Bank shot                         5
# Putback Dunk Shot                         5
# Hook Bank Shot                            5
# Driving Floating Jump Shot                5
# Running Finger Roll Shot                  4
# Running Pull-Up Jump Shot                 4
# Tip Layup Shot                            2
# Running Tip Shot                          2
# Turnaround Finger Roll Shot               2
# Putback Slam Dunk Shot                    2
# Running Slam Dunk Shot                    1
# Turnaround Fadeaway Bank Jump Shot        1
# Cutting Finger Roll Layup Shot            1
# Driving Floating Bank Jump Shot           1
# Name: action_type, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(x='action_type', data=df)
# Out:
# /home/yliu12/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
df.combined_shot_type.value_counts()
# Out:
# Jump Shot    23485
# Layup         5448
# Dunk          1286
# Tip Shot       184
# Hook Shot      153
# Bank Shot      141
# Name: combined_shot_type, dtype: int64

# %%
sns.countplot(x='combined_shot_type', data=df)
# Out:
# /home/yliu12/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
sns.set_style('whitegrid')
sns.pairplot(data=df, vars=['lat', 'lon', 'loc_x', 'loc_y'], hue='shot_made_flag')
# Out:
# /home/yliu12/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
not_needed.extend(['lon', 'lat'])

# %%
not_needed
# Out:
# ['game_event_id', 'game_id', 'team_id', 'team_name', 'matchup', 'lon', 'lat']

# %%
df['time_remaining'] = df['minutes_remaining']*60 + df['seconds_remaining']

# %%
not_needed.extend(['minutes_remaining', 'seconds_remaining'])

# %%
not_needed
# Out:
# ['game_event_id',
#  'game_id',
#  'team_id',
#  'team_name',
#  'matchup',
#  'lon',
#  'lat',
#  'minutes_remaining',
#  'seconds_remaining']

# %%
df.period.value_counts()
# Out:
# 3    8296
# 1    8048
# 4    7260
# 2    6718
# 5     330
# 6      38
# 7       7
# Name: period, dtype: int64

# %%
df.playoffs.value_counts()
# Out:
# 0    26198
# 1     4499
# Name: playoffs, dtype: int64

# %%
df.season.value_counts()
# Out:
# 2005-06    2318
# 2008-09    2242
# 2002-03    2241
# 2007-08    2153
# 2009-10    2080
# 2001-02    2028
# 2006-07    1887
# 2000-01    1868
# 2010-11    1825
# 2003-04    1638
# 2011-12    1637
# 2012-13    1593
# 1999-00    1577
# 2004-05    1324
# 2015-16    1113
# 1997-98     989
# 1998-99     921
# 2014-15     713
# 1996-97     477
# 2013-14      73
# Name: season, dtype: int64

# %%
df['season']=df['season'].apply(lambda x: x[:4])

# %%
df['season'] = pd.to_numeric(df['season'])

# %%
df.dtypes
# Out:
# action_type            object
# combined_shot_type     object
# game_event_id           int64
# game_id                 int64
# lat                   float64
# loc_x                   int64
# loc_y                   int64
# lon                   float64
# minutes_remaining       int64
# period                  int64
# playoffs                int64
# season                  int64
# seconds_remaining       int64
# shot_distance           int64
# shot_made_flag        float64
# shot_type              object
# shot_zone_area         object
# shot_zone_basic        object
# shot_zone_range        object
# team_id                 int64
# team_name              object
# game_date              object
# matchup                object
# opponent               object
# shot_id                 int64
# time_remaining          int64
# dtype: object

# %%
df.shot_distance.unique()
# Out:
# array([18, 15, 16, 22,  0, 14,  2, 12, 25, 17,  9,  5, 20, 11,  7, 26, 19,
#         8, 13,  1, 27, 28, 24, 23,  4, 21, 47, 10, 29, 42,  3, 48, 30, 45,
#         6, 33, 36, 62, 31, 70, 43, 38, 60, 37, 40, 32, 56, 35, 55, 51, 68,
#        39, 41, 64, 50, 49, 59, 54, 74, 44, 61, 65, 52, 34, 63, 46, 58, 69,
#        57, 53, 67, 71, 77, 79])

# %%
dist = pd.DataFrame({'true_dist': np.sqrt(df['loc_x']**2+df['loc_y']**2)/10, 'shot_distance': df['shot_distance']})
dist.head(10)
# Out:
#    shot_distance  true_dist
# 0             18  18.185984
# 1             15  15.700000
# 2             16  16.860012
# 3             22  22.286543
# 4              0   0.000000
# 5             14  14.541664
# 6              0   0.000000
# 7              2   2.801785
# 8             12  12.605158
# 9             12  12.928264

# %%
df['true_distance'] = dist['true_dist']
not_needed.append('shot_distance')

# %%
not_needed
# Out:
# ['game_event_id',
#  'game_id',
#  'team_id',
#  'team_name',
#  'matchup',
#  'lon',
#  'lat',
#  'minutes_remaining',
#  'seconds_remaining',
#  'shot_distance']

# %%
df.shot_type.value_counts()
# Out:
# 2PT Field Goal    24271
# 3PT Field Goal     6426
# Name: shot_type, dtype: int64

# %%
df['3pt_goal'] = df['shot_type'].str.contains('3PT').astype('int')
not_needed.append('shot_type')

# %%
df.columns
# Out:
# Index(['action_type', 'combined_shot_type', 'game_event_id', 'game_id', 'lat',
#        'loc_x', 'loc_y', 'lon', 'minutes_remaining', 'period', 'playoffs',
#        'season', 'seconds_remaining', 'shot_distance', 'shot_made_flag',
#        'shot_type', 'shot_zone_area', 'shot_zone_basic', 'shot_zone_range',
#        'team_id', 'team_name', 'game_date', 'matchup', 'opponent', 'shot_id',
#        'time_remaining', 'true_distance', '3pt_goal'],
#       dtype='object')

# %%
print(df.shot_zone_area.unique())
print(df.shot_zone_basic.unique())
print(df.shot_zone_range.unique())
# Out:
# ['Right Side(R)' 'Left Side(L)' 'Left Side Center(LC)'
#  'Right Side Center(RC)' 'Center(C)' 'Back Court(BC)']
# ['Mid-Range' 'Restricted Area' 'In The Paint (Non-RA)' 'Above the Break 3'
#  'Right Corner 3' 'Backcourt' 'Left Corner 3']
# ['16-24 ft.' '8-16 ft.' 'Less Than 8 ft.' '24+ ft.' 'Back Court Shot']

# %%
print(df.team_id.unique())
print(df.team_name.unique())
# Out:
# [1610612747]
# ['Los Angeles Lakers']

# %%
len(df.game_date.unique())
# Out:
# 1559

# %%
df.game_date.head()
# Out:
# 0    2000-10-31
# 1    2000-10-31
# 2    2000-10-31
# 3    2000-10-31
# 4    2000-10-31
# Name: game_date, dtype: object

# %%
df['game_date'] = pd.to_datetime(df['game_date'])

# %%
df['game_year'] = df['game_date'].dt.year
df['game_month'] = df['game_date'].dt.month
df['game_day'] = df['game_date'].dt.day
df['game_dayofweek'] = df['game_date'].dt.dayofweek
not_needed.append('game_date')

# %%
temp = df['matchup'].str.contains('vs.').astype('int')
df['game_at_home'] = temp
df.head().T
# Out:
#                                       0                    1  \
# action_type                   Jump Shot            Jump Shot
# combined_shot_type            Jump Shot            Jump Shot
# game_event_id                        10                   12
# game_id                        20000012             20000012
# lat                             33.9723              34.0443
# loc_x                               167                 -157
# loc_y                                72                    0
# lon                            -118.103             -118.427
# minutes_remaining                    10                   10
# period                                1                    1
# playoffs                              0                    0
# season                             2000                 2000
# seconds_remaining                    27                   22
# shot_distance                        18                   15
# shot_made_flag                      NaN                    0
# shot_type                2PT Field Goal       2PT Field Goal
# shot_zone_area            Right Side(R)         Left Side(L)
# shot_zone_basic               Mid-Range            Mid-Range
# shot_zone_range               16-24 ft.             8-16 ft.
# team_id                      1610612747           1610612747
# team_name            Los Angeles Lakers   Los Angeles Lakers
# game_date           2000-10-31 00:00:00  2000-10-31 00:00:00
# matchup                       LAL @ POR            LAL @ POR
# opponent                            POR                  POR
# shot_id                               1                    2
# time_remaining                      627                  622
# true_distance                    18.186                 15.7
# 3pt_goal                              0                    0
# game_year                          2000                 2000
# game_month                           10                   10
# game_day                             31                   31
# game_dayofweek                        1                    1
# game_at_home                          0                    0
#
#                                        2                      3  \
# action_type                    Jump Shot              Jump Shot
# combined_shot_type             Jump Shot              Jump Shot
# game_event_id                         35                     43
# game_id                         20000012               20000012
# lat                              33.9093                33.8693
# loc_x                               -101                    138
# loc_y                                135                    175
# lon                             -118.371               -118.132
# minutes_remaining                      7                      6
# period                                 1                      1
# playoffs                               0                      0
# season                              2000                   2000
# seconds_remaining                     45                     52
# shot_distance                         16                     22
# shot_made_flag                         1                      0
# shot_type                 2PT Field Goal         2PT Field Goal
# shot_zone_area      Left Side Center(LC)  Right Side Center(RC)
# shot_zone_basic                Mid-Range              Mid-Range
# shot_zone_range                16-24 ft.              16-24 ft.
# team_id                       1610612747             1610612747
# team_name             Los Angeles Lakers     Los Angeles Lakers
# game_date            2000-10-31 00:00:00    2000-10-31 00:00:00
# matchup                        LAL @ POR              LAL @ POR
# opponent                             POR                    POR
# shot_id                                3                      4
# time_remaining                       465                    412
# true_distance                      16.86                22.2865
# 3pt_goal                               0                      0
# game_year                           2000                   2000
# game_month                            10                     10
# game_day                              31                     31
# game_dayofweek                         1                      1
# game_at_home                           0                      0
#
#                                       4
# action_type           Driving Dunk Shot
# combined_shot_type                 Dunk
# game_event_id                       155
# game_id                        20000012
# lat                             34.0443
# loc_x                                 0
# loc_y                                 0
# lon                             -118.27
# minutes_remaining                     6
# period                                2
# playoffs                              0
# season                             2000
# seconds_remaining                    19
# shot_distance                         0
# shot_made_flag                        1
# shot_type                2PT Field Goal
# shot_zone_area                Center(C)
# shot_zone_basic         Restricted Area
# shot_zone_range         Less Than 8 ft.
# team_id                      1610612747
# team_name            Los Angeles Lakers
# game_date           2000-10-31 00:00:00
# matchup                       LAL @ POR
# opponent                            POR
# shot_id                               5
# time_remaining                      379
# true_distance                         0
# 3pt_goal                              0
# game_year                          2000
# game_month                           10
# game_day                             31
# game_dayofweek                        1
# game_at_home                          0

# %%
df.set_index('shot_id', inplace=True)

# %%
df.take(np.random.permutation(len(df))[:5]).T
# Out:
# shot_id                           17678                29768  \
# action_type                   Jump Shot       Slam Dunk Shot
# combined_shot_type            Jump Shot                 Dunk
# game_event_id                       172                  281
# game_id                        21000932             41100162
# lat                             33.9843              34.0353
# loc_x                              -120                    6
# loc_y                                60                    9
# lon                             -118.39             -118.264
# minutes_remaining                     4                   10
# period                                2                    3
# playoffs                              0                    1
# season                             2010                 2011
# seconds_remaining                    48                   16
# shot_distance                        13                    1
# shot_made_flag                        0                    1
# shot_type                2PT Field Goal       2PT Field Goal
# shot_zone_area             Left Side(L)            Center(C)
# shot_zone_basic               Mid-Range      Restricted Area
# shot_zone_range                8-16 ft.      Less Than 8 ft.
# team_id                      1610612747           1610612747
# team_name            Los Angeles Lakers   Los Angeles Lakers
# game_date           2011-03-06 00:00:00  2012-05-01 00:00:00
# matchup                       LAL @ SAS          LAL vs. DEN
# opponent                            SAS                  DEN
# time_remaining                      288                  616
# true_distance                   13.4164              1.08167
# 3pt_goal                              0                    0
# game_year                          2011                 2012
# game_month                            3                    5
# game_day                              6                    1
# game_dayofweek                        6                    1
# game_at_home                          0                    1
#
# shot_id                           11850                  29499  \
# action_type                  Layup Shot              Jump Shot
# combined_shot_type                Layup              Jump Shot
# game_event_id                       281                    466
# game_id                        20700300               40900405
# lat                             34.0443                33.8083
# loc_x                                 0                     99
# loc_y                                 0                    236
# lon                             -118.27               -118.171
# minutes_remaining                    11                      0
# period                                3                      4
# playoffs                              0                      1
# season                             2007                   2009
# seconds_remaining                    42                     12
# shot_distance                         0                     25
# shot_made_flag                        1                      0
# shot_type                2PT Field Goal         3PT Field Goal
# shot_zone_area                Center(C)  Right Side Center(RC)
# shot_zone_basic         Restricted Area      Above the Break 3
# shot_zone_range         Less Than 8 ft.                24+ ft.
# team_id                      1610612747             1610612747
# team_name            Los Angeles Lakers     Los Angeles Lakers
# game_date           2007-12-09 00:00:00    2010-06-13 00:00:00
# matchup                     LAL vs. GSW              LAL @ BOS
# opponent                            GSW                    BOS
# time_remaining                      702                     12
# true_distance                         0                25.5924
# 3pt_goal                              0                      1
# game_year                          2007                   2010
# game_month                           12                      6
# game_day                              9                     13
# game_dayofweek                        6                      6
# game_at_home                          1                      0
#
# shot_id                           29980
# action_type          Driving Layup Shot
# combined_shot_type                Layup
# game_event_id                       235
# game_id                        41100234
# lat                             34.0333
# loc_x                                20
# loc_y                                11
# lon                             -118.25
# minutes_remaining                     0
# period                                2
# playoffs                              1
# season                             2011
# seconds_remaining                     2
# shot_distance                         2
# shot_made_flag                      NaN
# shot_type                2PT Field Goal
# shot_zone_area                Center(C)
# shot_zone_basic         Restricted Area
# shot_zone_range         Less Than 8 ft.
# team_id                      1610612747
# team_name            Los Angeles Lakers
# game_date           2012-05-19 00:00:00
# matchup                     LAL vs. OKC
# opponent                            OKC
# time_remaining                        2
# true_distance                   2.28254
# 3pt_goal                              0
# game_year                          2012
# game_month                            5
# game_day                             19
# game_dayofweek                        5
# game_at_home                          1

# %%
df = df.drop(not_needed, axis=1)

# %%
df.shape
# Out:
# (30697, 20)

# %%
df.take(np.random.permutation(len(df))[:5]).T
# Out:
# shot_id                             17398                  29561  \
# action_type                     Jump Shot              Jump Shot
# combined_shot_type              Jump Shot              Jump Shot
# loc_x                                 127                    -27
# loc_y                                 138                     42
# period                                  3                      4
# playoffs                                0                      1
# season                               2010                   2010
# shot_made_flag                          0                      1
# shot_zone_area      Right Side Center(RC)              Center(C)
# shot_zone_basic                 Mid-Range  In The Paint (Non-RA)
# shot_zone_range                 16-24 ft.        Less Than 8 ft.
# opponent                              SAS                    NOH
# time_remaining                        688                    507
# true_distance                     18.7545                  4.993
# 3pt_goal                                0                      0
# game_year                            2011                   2011
# game_month                              2                      4
# game_day                                3                     17
# game_dayofweek                          3                      6
# game_at_home                            1                      1
#
# shot_id                         3186            11631                  27837
# action_type                 Jump Shot       Jump Shot              Jump Shot
# combined_shot_type          Jump Shot       Jump Shot              Jump Shot
# loc_x                              39             230                     77
# loc_y                             247             -16                    114
# period                              4               1                      4
# playoffs                            0               0                      1
# season                           2002            2007                   2005
# shot_made_flag                      0               0                      0
# shot_zone_area              Center(C)   Right Side(R)          Right Side(R)
# shot_zone_basic     Above the Break 3  Right Corner 3  In The Paint (Non-RA)
# shot_zone_range               24+ ft.         24+ ft.               8-16 ft.
# opponent                          POR             CHI                    PHX
# time_remaining                    106             156                    356
# true_distance                  25.006         23.0556                13.7568
# 3pt_goal                            1               1                      0
# game_year                        2002            2007                   2006
# game_month                         11              11                      4
# game_day                            3              18                     30
# game_dayofweek                      6               6                      6
# game_at_home                        1               1                      1

# %%
df.dtypes
# Out:
# action_type            object
# combined_shot_type     object
# loc_x                   int64
# loc_y                   int64
# period                  int64
# playoffs                int64
# season                  int64
# shot_made_flag        float64
# shot_zone_area         object
# shot_zone_basic        object
# shot_zone_range        object
# opponent               object
# time_remaining          int64
# true_distance         float64
# 3pt_goal                int64
# game_year               int64
# game_month              int64
# game_day                int64
# game_dayofweek          int64
# game_at_home            int64
# dtype: object

# %%
df.to_csv('data_cleaned.csv')

# %%
df2 = pd.read_csv('data_cleaned.csv', index_col ='shot_id')
df2.dtypes
# Out:
# action_type            object
# combined_shot_type     object
# loc_x                   int64
# loc_y                   int64
# period                  int64
# playoffs                int64
# season                  int64
# shot_made_flag        float64
# shot_zone_area         object
# shot_zone_basic        object
# shot_zone_range        object
# opponent               object
# time_remaining          int64
# true_distance         float64
# 3pt_goal                int64
# game_year               int64
# game_month              int64
# game_day                int64
# game_dayofweek          int64
# game_at_home            int64
# dtype: object

# %%
df2.take(np.random.permutation(len(df2))[:5]).T
# Out:
# shot_id                             11739               26304  \
# action_type                     Jump Shot  Driving Layup Shot
# combined_shot_type              Jump Shot               Layup
# loc_x                                 120                   0
# loc_y                                 117                   0
# period                                  3                   2
# playoffs                                0                   1
# season                               2007                2000
# shot_made_flag                          1                   0
# shot_zone_area      Right Side Center(RC)           Center(C)
# shot_zone_basic                 Mid-Range     Restricted Area
# shot_zone_range                 16-24 ft.     Less Than 8 ft.
# opponent                              SEA                 SAC
# time_remaining                        173                 257
# true_distance                     16.7598                   0
# 3pt_goal                                0                   0
# game_year                            2007                2001
# game_month                             11                   5
# game_day                               27                  11
# game_dayofweek                          1                   4
# game_at_home                            1                   0
#
# shot_id                             16040           599        3183
# action_type          Turnaround Jump Shot       Jump Shot  Jump Shot
# combined_shot_type              Jump Shot       Jump Shot  Jump Shot
# loc_x                                 -62             237         -3
# loc_y                                  69              21        196
# period                                  3               4          4
# playoffs                                0               0          0
# season                               2009            2000       2002
# shot_made_flag                          0               0          1
# shot_zone_area               Left Side(L)   Right Side(R)  Center(C)
# shot_zone_basic     In The Paint (Non-RA)  Right Corner 3  Mid-Range
# shot_zone_range                  8-16 ft.         24+ ft.  16-24 ft.
# opponent                              DAL             TOR        POR
# time_remaining                        595             208        349
# true_distance                     9.27631         23.7929    19.6023
# 3pt_goal                                0               1          0
# game_year                            2010            2000       2002
# game_month                              2              12         11
# game_day                               24              17          3
# game_dayofweek                          2               6          6
# game_at_home                            0               0          1

# %%
df2.shape == df.shape
# Out:
# True

# %% [markdown]
# # Explore data

# %% [markdown]
# ## 1. Analyse game trend

# %%
match_df = df[['game_year', 'game_month', 'game_day', 'opponent']]

# %%
print(match_df.shape)
match_df = match_df.drop_duplicates()
print(match_df.shape)
# Out:
# (30697, 4)
# (1559, 4)

# %%
plt.figure(figsize=(14,8))
plt.title('Opponent counts LA played with')
sns.countplot(y='opponent', data=match_df)
# Out:
# /home/yliu12/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ![nba_team_map](http://www.fb-ninja.com/Content/images/logos/nba_team_map.jpg)

# %% [markdown]
# #### LA plays more games with western teams

# %%
plt.figure(figsize=(14,8))
plt.title('Games LA played in each year')
sns.countplot(x='game_year', data=match_df)
# Out:
# /home/yliu12/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.figure(figsize=(14,8))
plt.title('Games LA played in each month')
sns.countplot(x='game_month', data=match_df)
# Out:
# /home/yliu12/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.figure(figsize=(14,8))
plt.title('Games LA played in each day')
sns.countplot(x='game_day', data=match_df)
# Out:
# /home/yliu12/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
df[(df['game_year']==2016) & (df['game_month']==4) & (df['game_day']==13)]
# Out:
#                         action_type combined_shot_type  loc_x  loc_y  period  \
# shot_id
# 22852                     Jump Shot          Jump Shot    137    203       1
# 22853                     Jump Shot          Jump Shot    199     11       1
# 22854                    Layup Shot              Layup     19      2       1
# 22855          Turnaround Jump Shot          Jump Shot      6     46       1
# 22856                     Jump Shot          Jump Shot    -61    165       1
# 22857              Pullup Jump shot          Jump Shot   -104      7       1
# 22858              Pullup Jump shot          Jump Shot    -32    154       1
# 22859    Driving Reverse Layup Shot              Layup    -17    -11       1
# 22860                     Jump Shot          Jump Shot    197     -6       1
# 22861              Pullup Jump shot          Jump Shot    195    139       1
# 22862                     Jump Shot          Jump Shot    122    219       1
# 22863                     Jump Shot          Jump Shot   -166    188       1
# 22864                     Jump Shot          Jump Shot    -34    237       1
# 22865                     Jump Shot          Jump Shot   -223    -11       2
# 22866            Driving Layup Shot              Layup      6     -5       2
# 22867                     Jump Shot          Jump Shot   -156    188       2
# 22868                     Jump Shot          Jump Shot   -183    193       2
# 22869                     Jump Shot          Jump Shot   -217    120       2
# 22870                    Layup Shot              Layup    -19     -1       2
# 22871            Fadeaway Jump Shot          Jump Shot     40    111       2
# 22872            Driving Layup Shot              Layup     -2      7       3
# 22873          Turnaround Jump Shot          Jump Shot    -45     75       3
# 22874                     Jump Shot          Jump Shot    -96    237       3
# 22875            Driving Layup Shot              Layup     -4      0       3
# 22876                     Jump Shot          Jump Shot    -32    313       3
# 22877              Pullup Jump shot          Jump Shot    -40    115       3
# 22878                     Jump Shot          Jump Shot     82    237       3
# 22879                     Jump Shot          Jump Shot   -187    193       3
# 22880            Driving Layup Shot              Layup     15      3       3
# 22881              Pullup Jump shot          Jump Shot    122     -6       3
# 22882                     Jump Shot          Jump Shot    228     26       3
# 22883                     Jump Shot          Jump Shot    179    169       3
# 22884                    Layup Shot              Layup    -16      0       3
# 22885              Pullup Jump shot          Jump Shot   -168    205       3
# 22886                     Jump Shot          Jump Shot   -237    -10       4
# 22887                     Jump Shot          Jump Shot    110    131       4
# 22888                    Layup Shot              Layup      6     -1       4
# 22889                     Jump Shot          Jump Shot   -168    198       4
# 22890              Pullup Jump shot          Jump Shot     43    237       4
# 22891                     Jump Shot          Jump Shot    166    180       4
# 22892                     Jump Shot          Jump Shot     -1     51       4
# 22893              Pullup Jump shot          Jump Shot     -7    111       4
# 22894              Pullup Jump shot          Jump Shot     50     85       4
# 22895      Turnaround Fadeaway shot          Jump Shot    -83    -11       4
# 22896                    Layup Shot              Layup     -7     -6       4
# 22897            Reverse Layup Shot              Layup      6     -6       4
# 22898            Driving Layup Shot              Layup     -7      2       4
# 22899              Pullup Jump shot          Jump Shot     69    129       4
# 22900              Pullup Jump shot          Jump Shot   -232    110       4
# 22901              Pullup Jump shot          Jump Shot     58    188       4
#
#          playoffs  season  shot_made_flag         shot_zone_area  \
# shot_id
# 22852           0    2015             0.0  Right Side Center(RC)
# 22853           0    2015             0.0          Right Side(R)
# 22854           0    2015             0.0              Center(C)
# 22855           0    2015             0.0              Center(C)
# 22856           0    2015             0.0   Left Side Center(LC)
# 22857           0    2015             1.0           Left Side(L)
# 22858           0    2015             1.0              Center(C)
# 22859           0    2015             1.0              Center(C)
# 22860           0    2015             1.0          Right Side(R)
# 22861           0    2015             1.0  Right Side Center(RC)
# 22862           0    2015             NaN  Right Side Center(RC)
# 22863           0    2015             0.0   Left Side Center(LC)
# 22864           0    2015             0.0              Center(C)
# 22865           0    2015             0.0           Left Side(L)
# 22866           0    2015             1.0              Center(C)
# 22867           0    2015             1.0   Left Side Center(LC)
# 22868           0    2015             0.0   Left Side Center(LC)
# 22869           0    2015             0.0   Left Side Center(LC)
# 22870           0    2015             0.0              Center(C)
# 22871           0    2015             0.0              Center(C)
# 22872           0    2015             1.0              Center(C)
# 22873           0    2015             1.0           Left Side(L)
# 22874           0    2015             0.0   Left Side Center(LC)
# 22875           0    2015             NaN              Center(C)
# 22876           0    2015             0.0              Center(C)
# 22877           0    2015             NaN              Center(C)
# 22878           0    2015             0.0  Right Side Center(RC)
# 22879           0    2015             0.0   Left Side Center(LC)
# 22880           0    2015             1.0              Center(C)
# 22881           0    2015             1.0          Right Side(R)
# 22882           0    2015             1.0          Right Side(R)
# 22883           0    2015             0.0  Right Side Center(RC)
# 22884           0    2015             1.0              Center(C)
# 22885           0    2015             0.0   Left Side Center(LC)
# 22886           0    2015             0.0           Left Side(L)
# 22887           0    2015             NaN  Right Side Center(RC)
# 22888           0    2015             0.0              Center(C)
# 22889           0    2015             1.0   Left Side Center(LC)
# 22890           0    2015             1.0              Center(C)
# 22891           0    2015             0.0  Right Side Center(RC)
# 22892           0    2015             NaN              Center(C)
# 22893           0    2015             1.0              Center(C)
# 22894           0    2015             0.0          Right Side(R)
# 22895           0    2015             0.0           Left Side(L)
# 22896           0    2015             0.0              Center(C)
# 22897           0    2015             1.0              Center(C)
# 22898           0    2015             1.0              Center(C)
# 22899           0    2015             NaN              Center(C)
# 22900           0    2015             1.0   Left Side Center(LC)
# 22901           0    2015             NaN              Center(C)
#
#                shot_zone_basic  shot_zone_range opponent  time_remaining  \
# shot_id
# 22852        Above the Break 3          24+ ft.      UTA             685
# 22853                Mid-Range        16-24 ft.      UTA             644
# 22854          Restricted Area  Less Than 8 ft.      UTA             539
# 22855    In The Paint (Non-RA)  Less Than 8 ft.      UTA             460
# 22856                Mid-Range        16-24 ft.      UTA             334
# 22857                Mid-Range         8-16 ft.      UTA             312
# 22858                Mid-Range         8-16 ft.      UTA             285
# 22859          Restricted Area  Less Than 8 ft.      UTA             254
# 22860                Mid-Range        16-24 ft.      UTA             200
# 22861        Above the Break 3          24+ ft.      UTA             180
# 22862        Above the Break 3          24+ ft.      UTA             148
# 22863        Above the Break 3          24+ ft.      UTA              75
# 22864        Above the Break 3          24+ ft.      UTA              36
# 22865            Left Corner 3          24+ ft.      UTA             358
# 22866          Restricted Area  Less Than 8 ft.      UTA             296
# 22867        Above the Break 3          24+ ft.      UTA             219
# 22868        Above the Break 3          24+ ft.      UTA             188
# 22869        Above the Break 3          24+ ft.      UTA             155
# 22870          Restricted Area  Less Than 8 ft.      UTA              84
# 22871    In The Paint (Non-RA)         8-16 ft.      UTA               0
# 22872          Restricted Area  Less Than 8 ft.      UTA             633
# 22873    In The Paint (Non-RA)         8-16 ft.      UTA             609
# 22874        Above the Break 3          24+ ft.      UTA             585
# 22875          Restricted Area  Less Than 8 ft.      UTA             580
# 22876        Above the Break 3          24+ ft.      UTA             540
# 22877    In The Paint (Non-RA)         8-16 ft.      UTA             521
# 22878        Above the Break 3          24+ ft.      UTA             456
# 22879        Above the Break 3          24+ ft.      UTA             399
# 22880          Restricted Area  Less Than 8 ft.      UTA             336
# 22881                Mid-Range         8-16 ft.      UTA             303
# 22882           Right Corner 3          24+ ft.      UTA             252
# 22883        Above the Break 3          24+ ft.      UTA             181
# 22884          Restricted Area  Less Than 8 ft.      UTA              61
# 22885        Above the Break 3          24+ ft.      UTA               2
# 22886            Left Corner 3          24+ ft.      UTA             678
# 22887                Mid-Range        16-24 ft.      UTA             622
# 22888          Restricted Area  Less Than 8 ft.      UTA             604
# 22889        Above the Break 3          24+ ft.      UTA             571
# 22890        Above the Break 3          24+ ft.      UTA             538
# 22891        Above the Break 3          24+ ft.      UTA             502
# 22892    In The Paint (Non-RA)  Less Than 8 ft.      UTA             404
# 22893    In The Paint (Non-RA)         8-16 ft.      UTA             341
# 22894    In The Paint (Non-RA)         8-16 ft.      UTA             305
# 22895                Mid-Range         8-16 ft.      UTA             267
# 22896          Restricted Area  Less Than 8 ft.      UTA             232
# 22897          Restricted Area  Less Than 8 ft.      UTA             185
# 22898          Restricted Area  Less Than 8 ft.      UTA             105
# 22899    In The Paint (Non-RA)         8-16 ft.      UTA              87
# 22900        Above the Break 3          24+ ft.      UTA              59
# 22901                Mid-Range        16-24 ft.      UTA              31
#
#          true_distance  3pt_goal  game_year  game_month  game_day  \
# shot_id
# 22852        24.490406         1       2016           4        13
# 22853        19.930379         0       2016           4        13
# 22854         1.910497         0       2016           4        13
# 22855         4.638965         0       2016           4        13
# 22856        17.591475         0       2016           4        13
# 22857        10.423531         0       2016           4        13
# 22858        15.728954         0       2016           4        13
# 22859         2.024846         0       2016           4        13
# 22860        19.709135         0       2016           4        13
# 22861        23.947025         1       2016           4        13
# 22862        25.068905         1       2016           4        13
# 22863        25.079872         1       2016           4        13
# 22864        23.942640         1       2016           4        13
# 22865        22.327114         1       2016           4        13
# 22866         0.781025         0       2016           4        13
# 22867        24.429490         1       2016           4        13
# 22868        26.596616         1       2016           4        13
# 22869        24.796976         1       2016           4        13
# 22870         1.902630         0       2016           4        13
# 22871        11.798729         0       2016           4        13
# 22872         0.728011         0       2016           4        13
# 22873         8.746428         0       2016           4        13
# 22874        25.570491         1       2016           4        13
# 22875         0.400000         0       2016           4        13
# 22876        31.463153         1       2016           4        13
# 22877        12.175796         0       2016           4        13
# 22878        25.078477         1       2016           4        13
# 22879        26.873407         1       2016           4        13
# 22880         1.529706         0       2016           4        13
# 22881        12.214745         0       2016           4        13
# 22882        22.947767         1       2016           4        13
# 22883        24.617473         1       2016           4        13
# 22884         1.600000         0       2016           4        13
# 22885        26.504528         1       2016           4        13
# 22886        23.721088         1       2016           4        13
# 22887        17.105847         0       2016           4        13
# 22888         0.608276         0       2016           4        13
# 22889        25.966902         1       2016           4        13
# 22890        24.086926         1       2016           4        13
# 22891        24.485914         1       2016           4        13
# 22892         5.100980         0       2016           4        13
# 22893        11.122050         0       2016           4        13
# 22894         9.861541         0       2016           4        13
# 22895         8.372574         0       2016           4        13
# 22896         0.921954         0       2016           4        13
# 22897         0.848528         0       2016           4        13
# 22898         0.728011         0       2016           4        13
# 22899        14.629422         0       2016           4        13
# 22900        25.675669         1       2016           4        13
# 22901        19.674349         0       2016           4        13
#
#          game_dayofweek  game_at_home
# shot_id
# 22852                 2             1
# 22853                 2             1
# 22854                 2             1
# 22855                 2             1
# 22856                 2             1
# 22857                 2             1
# 22858                 2             1
# 22859                 2             1
# 22860                 2             1
# 22861                 2             1
# 22862                 2             1
# 22863                 2             1
# 22864                 2             1
# 22865                 2             1
# 22866                 2             1
# 22867                 2             1
# 22868                 2             1
# 22869                 2             1
# 22870                 2             1
# 22871                 2             1
# 22872                 2             1
# 22873                 2             1
# 22874                 2             1
# 22875                 2             1
# 22876                 2             1
# 22877                 2             1
# 22878                 2             1
# 22879                 2             1
# 22880                 2             1
# 22881                 2             1
# 22882                 2             1
# 22883                 2             1
# 22884                 2             1
# 22885                 2             1
# 22886                 2             1
# 22887                 2             1
# 22888                 2             1
# 22889                 2             1
# 22890                 2             1
# 22891                 2             1
# 22892                 2             1
# 22893                 2             1
# 22894                 2             1
# 22895                 2             1
# 22896                 2             1
# 22897                 2             1
# 22898                 2             1
# 22899                 2             1
# 22900                 2             1
# 22901                 2             1

# %%
df.groupby(['game_year', 'game_month', 'game_day', 'opponent']).agg({'count': np.sum})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/yliu12/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'count'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-362-6ce91140f70c> in <module>()
# ----> 1 df.groupby(['game_year', 'game_month', 'game_day', 'opponent']).agg({'count': np.sum})
#
# /home/yliu12/anaconda3/lib/python3.5/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    3702     @Appender(SelectionMixin._agg_doc)
#    3703     def aggregate(self, arg, *args, **kwargs):
# -> 3704         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    3705
#    3706     agg = aggregate
#
# /home/yliu12/anaconda3/lib/python3.5/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    3191
#    3192         _level = kwargs.pop('_level', None)
# -> 3193         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#    3194         if how is None:
#    3195             return result
#
# /home/yliu12/anaconda3/lib/python3.5/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     547
#     548                 try:
# --> 549                     result = _agg(arg, _agg_1dim)
#     550                 except SpecificationError:
#     551
#
# /home/yliu12/anaconda3/lib/python3.5/site-packages/pandas/core/base.py in _agg(arg, func)
#     498                 result = compat.OrderedDict()
#     499                 for fname, agg_how in compat.iteritems(arg):
# --> 500                     result[fname] = func(fname, agg_how)
#     501                 return result
#     502
#
# /home/yliu12/anaconda3/lib/python3.5/site-packages/pandas/core/base.py in _agg_1dim(name, how, subset)
#     477                 aggregate a 1-dim with how
#     478                 """
# --> 479                 colg = self._gotitem(name, ndim=1, subset=subset)
#     480                 if colg.ndim != 1:
#     481                     raise SpecificationError("nested dictionary is ambiguous "
#
# /home/yliu12/anaconda3/lib/python3.5/site-packages/pandas/core/groupby.py in _gotitem(self, key, ndim, subset)
#    3729         elif ndim == 1:
#    3730             if subset is None:
# -> 3731                 subset = self.obj[key]
#    3732             return SeriesGroupBy(subset, selection=key,
#    3733                                  grouper=self.grouper)
#
# /home/yliu12/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /home/yliu12/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /home/yliu12/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /home/yliu12/anaconda3/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/yliu12/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'count'

# %% [markdown]
# ## 2. Analyse score statistics

# %%
area_group = df.groupby('shot_zone_area')
basic_group = df.groupby('shot_zone_basic')
range_group = df.groupby('shot_zone_range')

# %%
plt.subplots(1, 3, figsize=(14, 7), sharey=True)
colors = list('rgbcmyk')

plt.subplot(131)
plt.ylim(800, -50)
plt.title('shot_zone_area')
for i, (_, area) in enumerate(area_group):
    plt.scatter(area['loc_x'], area['loc_y'], alpha=0.1, color=colors[i])
    
plt.subplot(132)
plt.ylim(800, -50)
plt.title('shot_zone_basic')
for i, (_, basic) in enumerate(basic_group):
    plt.scatter(basic['loc_x'], basic['loc_y'], alpha=0.1, color=colors[i])

    
plt.subplot(133)
plt.ylim(800, -50)
plt.title('shot_zone_range')
for i, (_, shot_zone_range) in enumerate(range_group):
    plt.scatter(shot_zone_range['loc_x'], shot_zone_range['loc_y'], alpha=0.1, color=colors[i])
# Out:
# /home/yliu12/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
df['loc_x'].describe()
# Out:
# count    30697.000000
# mean         7.110499
# std        110.124578
# min       -250.000000
# 25%        -68.000000
# 50%          0.000000
# 75%         95.000000
# max        248.000000
# Name: loc_x, dtype: float64

# %%
df['loc_y'].describe()
# Out:
# count    30697.000000
# mean        91.107535
# std         87.791361
# min        -44.000000
# 25%          4.000000
# 50%         74.000000
# 75%        160.000000
# max        791.000000
# Name: loc_y, dtype: float64

# %%
plt.figure(figsize=(14,8))
sns.countplot(y='opponent', data=df)
# Out:
# /home/yliu12/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# #### Koby scores more in western competitions.

# %%
plt.figure(figsize=(14,8))
plt.title("Kobe's scores through his career 1996-2016")
sns.countplot(x='game_year', data=df)
# Out:
# /home/yliu12/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.figure(figsize=(14,8))
plt.title('Shots in month, year 2002')
sns.countplot(x='game_month', data=df[df['game_year']==2002])
# Out:
# /home/yliu12/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
